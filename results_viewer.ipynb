# %% [markdown]
# ## Qwen SF11 FasterOpt

# %%
import matplotlib.pyplot as plt

# Data for plotting
context_lengths = [
    2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096
]

# Perplexity values for each context length at each epoch
perplexities_epoch_1 = [
    4322.30858495819, 1781.3902492192703, 1589.7688925400646, 1477.048900299589, 
    1089.506116391083, 1064.7905315595945, 985.899339151297, 983.7327734167133, 
    996.02966180956, 14088.325113448078, 33327.8080415587, 98112.5846369078
]

perplexities_epoch_2 = [
    3718.487178809328, 1581.030762057598, 1396.0495105417476, 1356.3231416758113, 
    905.5955868796793, 794.7963560590989, 776.3232836849636, 702.7035812548113, 
    996.02966180956, 89995.48229238954, 455190.1193918647, 1337277.623955364
]

perplexities_epoch_3 = [
    3463.2636263721424, 1764.688008355325, 1458.9876215390964, 1221.1192510354522, 
    879.4182704818412, 856.9278264276489, 794.7963560590989, 702.7035812548113, 
    996.02966180956, 48701.90207101852, 1580989.4116876964, 2375066.4593955874
]

# Plotting the graphs
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

x_ticks = [2**i for i in range(13)]

# Plot for epoch 1
axes[0].plot(context_lengths, perplexities_epoch_1, marker='o', color='b')
axes[0].set_title("Perplexity for Epoch 1")
axes[0].set_xlabel("Context Length")
axes[0].set_ylabel("Perplexity")
axes[0].set_xscale('log', base=2)
axes[0].set_yscale('log')
axes[0].set_xticks(x_ticks)
axes[0].grid(True)

# Plot for epoch 2
axes[1].plot(context_lengths, perplexities_epoch_2, marker='o', color='g')
axes[1].set_title("Perplexity for Epoch 2")
axes[1].set_xlabel("Context Length")
axes[1].set_ylabel("Perplexity")
axes[1].set_xscale('log', base=2)
axes[1].set_yscale('log')
axes[1].set_xticks(x_ticks)
axes[1].grid(True)

# Plot for epoch 3
axes[2].plot(context_lengths, perplexities_epoch_3, marker='o', color='r')
axes[2].set_title("Perplexity for Epoch 3")
axes[2].set_xlabel("Context Length")
axes[2].set_ylabel("Perplexity")
axes[2].set_xscale('log', base=2)
axes[2].set_yscale('log')
axes[2].set_xticks(x_ticks)
axes[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Qwen SF8 FasterOpt

# %%
import matplotlib.pyplot as plt

# Given values for the perplexities
sf8_values = {
    'sf8_4_1_opt': 2803.214389602731,
    'sf8_4_2_opt': 2660.7256764995223,
    'sf8_4_3_opt': 2666.113309442748,
    'sf8_8_1_opt': 2390.5952655098586,
    'sf8_8_2_opt': 2141.4051571169643,
    'sf8_8_3_opt': 2091.3998932419627,
    'sf8_16_1_opt': 2093.9585662185373,
    'sf8_16_2_opt': 1908.7356707237318,
    'sf8_16_3_opt': 1812.393351324097,
    'sf8_32_1_opt': 1880.2659005273554,
    'sf8_32_2_opt': 1685.1704335413092,
    'sf8_32_3_opt': 1638.9568841596497,
    'sf8_64_1_opt': 1790.5554292728596,
    'sf8_64_2_opt': 1603.1744439209203,
    'sf8_64_3_opt': 1533.1676084696594,
    'sf8_128_1_opt': 1730.3713138278702,
    'sf8_128_2_opt': 1558.5827629409969,
    'sf8_128_3_opt': 1504.809224987049,
    'sf8_256_1_opt': 1765.6081894154902,
    'sf8_256_2_opt': 1605.1590781850991,
    'sf8_256_3_opt': 1521.144874472467,
    'sf8_512_1_opt': 1911.216539946288,
    'sf8_512_2_opt': 1686.4773288446459,
    'sf8_512_3_opt': 1616.7194757421662,
    'sf8_1024_1_opt': 2095.2290202286867,
    'sf8_1024_2_opt': 1854.6059288445804,
    'sf8_1024_3_opt': 1758.3046249666197,
    'sf8_2048_1_opt': 2558.4375385405224,
    'sf8_2048_2_opt': 2161.7429579609634,
    'sf8_2048_3_opt': 2073.5884959014425,
    'sf8_4096_1_opt': 2209.3391565179663,
    'sf8_4096_2_opt': 1994.4948576908382,
    'sf8_4096_3_opt': 1922.3558727903353,
}

# Context lengths corresponding to the keys
context_lengths = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# Define the perplexities for each epoch (using the `sf8_*_opt` values)
perplexities_epoch_1 = [
    sf8_values['sf8_4_1_opt'], sf8_values['sf8_8_1_opt'], sf8_values['sf8_16_1_opt'], sf8_values['sf8_32_1_opt'],
    sf8_values['sf8_64_1_opt'], sf8_values['sf8_128_1_opt'], sf8_values['sf8_256_1_opt'], sf8_values['sf8_512_1_opt'],
    sf8_values['sf8_1024_1_opt'], sf8_values['sf8_2048_1_opt'], sf8_values['sf8_4096_1_opt']
]

perplexities_epoch_2 = [
    sf8_values['sf8_4_2_opt'], sf8_values['sf8_8_2_opt'], sf8_values['sf8_16_2_opt'], sf8_values['sf8_32_2_opt'],
    sf8_values['sf8_64_2_opt'], sf8_values['sf8_128_2_opt'], sf8_values['sf8_256_2_opt'], sf8_values['sf8_512_2_opt'],
    sf8_values['sf8_1024_2_opt'], sf8_values['sf8_2048_2_opt'], sf8_values['sf8_4096_2_opt']
]

perplexities_epoch_3 = [
    sf8_values['sf8_4_3_opt'], sf8_values['sf8_8_3_opt'], sf8_values['sf8_16_3_opt'], sf8_values['sf8_32_3_opt'],
    sf8_values['sf8_64_3_opt'], sf8_values['sf8_128_3_opt'], sf8_values['sf8_256_3_opt'], sf8_values['sf8_512_3_opt'],
    sf8_values['sf8_1024_3_opt'], sf8_values['sf8_2048_3_opt'], sf8_values['sf8_4096_3_opt']
]

# Plotting the graphs
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

x_ticks = [2**i for i in range(13)]

# Plot for epoch 1
axes[0].plot(context_lengths, perplexities_epoch_1, marker='o', color='b')
axes[0].set_title("Perplexity for Epoch 1")
axes[0].set_xlabel("Context Length")
axes[0].set_ylabel("Perplexity")
axes[0].set_xscale('log', base=2)
axes[0].set_yscale('log')
axes[0].set_xticks(x_ticks)
axes[0].grid(True)

# Plot for epoch 2
axes[1].plot(context_lengths, perplexities_epoch_2, marker='o', color='g')
axes[1].set_title("Perplexity for Epoch 2")
axes[1].set_xlabel("Context Length")
axes[1].set_ylabel("Perplexity")
axes[1].set_xscale('log', base=2)
axes[1].set_yscale('log')
axes[1].set_xticks(x_ticks)
axes[1].grid(True)

# Plot for epoch 3
axes[2].plot(context_lengths, perplexities_epoch_3, marker='o', color='r')
axes[2].set_title("Perplexity for Epoch 3")
axes[2].set_xlabel("Context Length")
axes[2].set_ylabel("Perplexity")
axes[2].set_xscale('log', base=2)
axes[2].set_yscale('log')
axes[2].set_xticks(x_ticks)
axes[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Qwen SF16 FasterOpt

# %%
import matplotlib.pyplot as plt

# Given values for the perplexities
sf16_values = {
    'sf16_2_1_opt': 9094.22956593173,
    'sf16_2_2_opt': 7307.924874821404,
    'sf16_2_3_opt': 7145.136261478645,
    'sf16_4_1_opt': 1891.0066527317445,
    'sf16_4_2_opt': 1766.2354413283058,
    'sf16_4_3_opt': 1647.6271714554487,
    'sf16_8_1_opt': 1172.7496587695935,
    'sf16_8_2_opt': 1104.0318541808851,
    'sf16_8_3_opt': 1032.5155744273404,
    'sf16_16_1_opt': 1012.6546907271078,
    'sf16_16_2_opt': 843.3774059518261,
    'sf16_16_3_opt': 727.2314487982262,
    'sf16_32_1_opt': 834.3253490103832,
    'sf16_32_2_opt': 653.4774403894025,
    'sf16_32_3_opt': 588.8658544224729,
    'sf16_64_1_opt': 737.5024307135495,
    'sf16_64_2_opt': 545.9168604360921,
    'sf16_64_3_opt': 470.7320192439982,
    'sf16_128_1_opt': 666.9694545360657,
    'sf16_128_2_opt': 506.6323613453804,
    'sf16_128_3_opt': 408.9385333487627,
    'sf16_256_1_opt': 643.7127243479607,
    'sf16_256_2_opt': 466.61720519226355,
    'sf16_256_3_opt': 395.2464733233943,
    'sf16_512_1_opt': 687.8976354274207,
    'sf16_512_2_opt': 489.41525977703947,
    'sf16_512_3_opt': 417.94871794871793,
    'sf16_1024_1_opt': 722.2308899158264,
    'sf16_1024_2_opt': 538.1662184558193,
    'sf16_1024_3_opt': 451.60910238248135,
    'sf16_2048_1_opt': 869.5968841814088,
    'sf16_2048_2_opt': 609.9411416630231,
    'sf16_2048_3_opt': 490.8998232706446,
    'sf16_4096_1_opt': 1055.809958928421,
    'sf16_4096_2_opt': 721.006161615113,
    'sf16_4096_3_opt': 571.474358974359,
}

# Context lengths corresponding to the keys
context_lengths = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# Define the perplexities for each epoch (using the `sf16_*_opt` values)
perplexities_epoch_1 = [
    sf16_values['sf16_2_1_opt'],
    sf16_values['sf16_4_1_opt'], sf16_values['sf16_8_1_opt'], sf16_values['sf16_16_1_opt'], sf16_values['sf16_32_1_opt'],
    sf16_values['sf16_64_1_opt'], sf16_values['sf16_128_1_opt'], sf16_values['sf16_256_1_opt'], sf16_values['sf16_512_1_opt'],
    sf16_values['sf16_1024_1_opt'], sf16_values['sf16_2048_1_opt'], sf16_values['sf16_4096_1_opt']
]

perplexities_epoch_2 = [
    sf16_values['sf16_2_2_opt'],
    sf16_values['sf16_4_2_opt'], sf16_values['sf16_8_2_opt'], sf16_values['sf16_16_2_opt'], sf16_values['sf16_32_2_opt'],
    sf16_values['sf16_64_2_opt'], sf16_values['sf16_128_2_opt'], sf16_values['sf16_256_2_opt'], sf16_values['sf16_512_2_opt'],
    sf16_values['sf16_1024_2_opt'], sf16_values['sf16_2048_2_opt'], sf16_values['sf16_4096_2_opt']
]

perplexities_epoch_3 = [
    sf16_values['sf16_2_3_opt'],
    sf16_values['sf16_4_3_opt'], sf16_values['sf16_8_3_opt'], sf16_values['sf16_16_3_opt'], sf16_values['sf16_32_3_opt'],
    sf16_values['sf16_64_3_opt'], sf16_values['sf16_128_3_opt'], sf16_values['sf16_256_3_opt'], sf16_values['sf16_512_3_opt'],
    sf16_values['sf16_1024_3_opt'], sf16_values['sf16_2048_3_opt'], sf16_values['sf16_4096_3_opt']
]

# Plotting the graphs
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

x_ticks = [2**i for i in range(13)]

# Plot for epoch 1
axes[0].plot(context_lengths, perplexities_epoch_1, marker='o', color='b')
axes[0].set_title("Perplexity for Epoch 1")
axes[0].set_xlabel("Context Length")
axes[0].set_ylabel("Perplexity")
axes[0].set_xscale('log', base=2)
axes[0].set_yscale('log')
axes[0].set_xticks(x_ticks)
axes[0].grid(True)

# Plot for epoch 2
axes[1].plot(context_lengths, perplexities_epoch_2, marker='o', color='g')
axes[1].set_title("Perplexity for Epoch 2")
axes[1].set_xlabel("Context Length")
axes[1].set_ylabel("Perplexity")
axes[1].set_xscale('log', base=2)
axes[1].set_yscale('log')
axes[1].set_xticks(x_ticks)
axes[1].grid(True)

# Plot for epoch 3
axes[2].plot(context_lengths, perplexities_epoch_3, marker='o', color='r')
axes[2].set_title("Perplexity for Epoch 3")
axes[2].set_xlabel("Context Length")
axes[2].set_ylabel("Perplexity")
axes[2].set_xscale('log', base=2)
axes[2].set_yscale('log')
axes[2].set_xticks(x_ticks)
axes[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Qwen SF4 FasterOpt

# %%
import matplotlib.pyplot as plt

# Given values for the perplexities
sf4_values = {
    'sf4_2_1_opt': 54167.649784965644,
    'sf4_2_2_opt': 48589.70806149329,
    'sf4_2_3_opt': 46615.565898616434,
    'sf4_4_1_opt': 36354.15270298341,
    'sf4_4_2_opt': 33370.051148068735,
    'sf4_4_3_opt': 32862.751713992635,
    'sf4_8_1_opt': 31097.47204222733,
    'sf4_8_2_opt': 30056.25615286889,
    'sf4_8_3_opt': 29932.51073431043,
    'sf4_16_1_opt': 27862.13702469161,
    'sf4_16_2_opt': 27359.98937723281,
    'sf4_16_3_opt': 27473.420514308655,
    'sf4_32_1_opt': 26038.251398909735,
    'sf4_32_2_opt': 25562.0183439515,
    'sf4_32_3_opt': 25579.64285246107,
    'sf4_64_1_opt': 24533.07828390292,
    'sf4_64_2_opt': 24138.3999512594,
    'sf4_64_3_opt': 24104.999428571875,
    'sf4_128_1_opt': 23568.917806054415,
    'sf4_128_2_opt': 23311.735145397146,
    'sf4_128_3_opt': 23242.13989350198,
    'sf4_256_1_opt': 23801.051283437686,
    'sf4_256_2_opt': 23452.845394363205,
    'sf4_256_3_opt': 23403.528692479867,
    'sf4_512_1_opt': 24438.658993457946,
    'sf4_512_2_opt': 24144.87036176574,
    'sf4_512_3_opt': 24099.45460802909,
    'sf4_1024_1_opt': 26023.03430406745,
    'sf4_1024_2_opt': 25661.398240184197,
    'sf4_1024_3_opt': 25567.256410964575,
    'sf4_2048_1_opt': 28031.769535139912,
    'sf4_2048_2_opt': 27218.84599875834,
    'sf4_2048_3_opt': 27045.90753367108,
    'sf4_4096_1_opt': 32423.535803336923,
    'sf4_4096_2_opt': 31949.248147915474,
    'sf4_4096_3_opt': 32862.751713992635
}

# Context lengths corresponding to the keys
context_lengths = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# Define the perplexities for each epoch (using the `sf4_*_opt` values)
perplexities_epoch_1 = [
    sf4_values['sf4_2_1_opt'],
    sf4_values['sf4_4_1_opt'], sf4_values['sf4_8_1_opt'], sf4_values['sf4_16_1_opt'], sf4_values['sf4_32_1_opt'],
    sf4_values['sf4_64_1_opt'], sf4_values['sf4_128_1_opt'], sf4_values['sf4_256_1_opt'], sf4_values['sf4_512_1_opt'],
    sf4_values['sf4_1024_1_opt'], sf4_values['sf4_2048_1_opt'], sf4_values['sf4_4096_1_opt']
]

perplexities_epoch_2 = [
    sf4_values['sf4_2_2_opt'],
    sf4_values['sf4_4_2_opt'], sf4_values['sf4_8_2_opt'], sf4_values['sf4_16_2_opt'], sf4_values['sf4_32_2_opt'],
    sf4_values['sf4_64_2_opt'], sf4_values['sf4_128_2_opt'], sf4_values['sf4_256_2_opt'], sf4_values['sf4_512_2_opt'],
    sf4_values['sf4_1024_2_opt'], sf4_values['sf4_2048_2_opt'], sf4_values['sf4_4096_2_opt']
]

perplexities_epoch_3 = [
    sf4_values['sf4_2_3_opt'],
    sf4_values['sf4_4_3_opt'], sf4_values['sf4_8_3_opt'], sf4_values['sf4_16_3_opt'], sf4_values['sf4_32_3_opt'],
    sf4_values['sf4_64_3_opt'], sf4_values['sf4_128_3_opt'], sf4_values['sf4_256_3_opt'], sf4_values['sf4_512_3_opt'],
    sf4_values['sf4_1024_3_opt'], sf4_values['sf4_2048_3_opt'], sf4_values['sf4_4096_3_opt']
]

# Plotting the graphs
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

x_ticks = [2**i for i in range(13)]

# Plot for epoch 1
axes[0].plot(context_lengths, perplexities_epoch_1, marker='o', color='b')
axes[0].set_title("Perplexity for Epoch 1")
axes[0].set_xlabel("Context Length")
axes[0].set_ylabel("Perplexity")
axes[0].set_xscale('log', base=2)
axes[0].set_yscale('log')
axes[0].set_xticks(x_ticks)
axes[0].grid(True)

# Plot for epoch 2
axes[1].plot(context_lengths, perplexities_epoch_2, marker='o', color='g')
axes[1].set_title("Perplexity for Epoch 2")
axes[1].set_xlabel("Context Length")
axes[1].set_ylabel("Perplexity")
axes[1].set_xscale('log', base=2)
axes[1].set_yscale('log')
axes[1].set_xticks(x_ticks)
axes[1].grid(True)

# Plot for epoch 3
axes[2].plot(context_lengths, perplexities_epoch_3, marker='o', color='r')
axes[2].set_title("Perplexity for Epoch 3")
axes[2].set_xlabel("Context Length")
axes[2].set_ylabel("Perplexity")
axes[2].set_xscale('log', base=2)
axes[2].set_yscale('log')
axes[2].set_xticks(x_ticks)
axes[2].grid(True)

plt.tight_layout()
plt.show()
